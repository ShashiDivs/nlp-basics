# %% [markdown]
# ## Integers

# %%
x = 25
year = 2025
neg_number = -9
b_number = 100000000

# %%
x
# Out:
# 25

# %%
a = 5
b = 3

# %%
a + b
# Out:
# 8

# %%
a * b
# Out:
# 15

# %%
a % b
# Out:
# 2

# %%
a // b
# Out:
# 1

# %% [markdown]
# # Float

# %%
price = 255.78
pi = 3.141
temp = -5.5

# %%
a = 5.4
b = 3.3

# %%
a + b
# Out:
# 8.7

# %% [markdown]
# ## Strings

# %%
name = "shashi"
city = 'Hyderabad'
huge_txt = """
Hi, this is string class and we are learing string methods too!
"""

# %%
name
# Out:
# 'shashi'

# %%
huge_txt
# Out:
# '\nHi, this is string class and we are learing string methods too!\n'

# %% [markdown]
# ## String Operations

# %%
len(name)
# Out:
# 6

# %%
type(name)
# Out:
# str

# %%
name.upper()
# Out:
# 'SHASHI'

# %%
x = 'PYTHON'
x.lower()
# Out:
# 'python'

# %%
x[0]
# Out:
# 'P'

# %%
x[-1]
# Out:
# 'N'

# %%
x[0:3]
# Out:
# 'PYT'

# %% [markdown]
# # String Methods

# %%
str_meth = "genAI is fantastic"

# %%
str_meth.capitalize()
# Out:
# 'Genai is fantastic'

# %%
str_meth.title()
# Out:
# 'Genai Is Fantastic'

# %%
str_meth.replace('fantastic','great')
# Out:
# 'genAI is great'

# %%
str_meth
# Out:
# 'genAI is fantastic'

# %%
str_meth.split()
# Out:
# ['genAI', 'is', 'fantastic']

# %%
huge_txt.split()
# Out:
# ['Hi,',
#  'this',
#  'is',
#  'string',
#  'class',
#  'and',
#  'we',
#  'are',
#  'learing',
#  'string',
#  'methods',
#  'too!']

# %%
f_name = 'shashi'
s_name = 'kumar'
f_names = f_name + "_" + s_name

# %%
f_names
# Out:
# 'shashi_kumar'

# %% [markdown]
# ## Join()

# %%
join_str = ["genAI", "is", "fantastic"]

# %%
join_str
# Out:
# ['genAI', 'is', 'fantastic']

# %%
j_str = ' '.join(join_str)

# %%
j_str
# Out:
# 'genAI is fantastic'

# %% [markdown]
# ## startswith() and endswith()

# %%
file_name = 'sasi.jpeg'
email = 'sasi@gmail.com'

# %%
file_name.startswith('pdf')
# Out:
# False

# %%
file_name.startswith('sasi')
# Out:
# True

# %%
email.endswith('.jpeg')
# Out:
# False

# %%
'@' in email
# Out:
# True

# %% [markdown]
# ## isdigit() isalpha()

# %%
nums = '12345'
nums.isdigit()
# Out:
# False

# %%
nums = '12345sasi'
nums.isalnum()
# Out:
# True

# %% [markdown]
# ## trimming and removing

# %%
review = "   This Movie is Bad and I give 1 rating.    "

review.strip()
# Out:
# 'This Movie is Bad and I give 1 rating.'

# %%
review.lstrip()
# Out:
# 'This Movie is Bad and I give 1 rating.    '

# %%
review.rstrip()
# Out:
# '   This Movie is Bad and I give 1 rating.'

# %% [markdown]
# # BOOLEANS True or False

# %%
is_class = True

# %%
is_class
# Out:
# True

# %%
5 > 3
# Out:
# True

# %%
10 != 4
# Out:
# True

# %% [markdown]
# ## LISTS

# %%
lang = ["c","c++","python","java","go"]

# %%
lang.append('javascript')

# %%
lang
# Out:
# ['c', 'c++', 'python', 'java', 'go', 'javascript']

# %%
type(lang)
# Out:
# list

# %%
nums = [20,30,50,60,70]
nums.insert(2,40)

# %%
nums
# Out:
# [20, 30, 40, 50, 60, 70]

# %%
x = ['kiwi','dragon','blueberries']
fruits = ['apple','orange']
fruits.extend(x)

# %%
fruits
# Out:
# ['apple', 'orange', 'kiwi', 'dragon', 'blueberries']

# %%
fruits = ['apple', 'orange', 'kiwi', 'dragon', 'blueberries']

# %%
fruits.remove('apple')

# %%
fruits
# Out:
# ['orange', 'kiwi', 'dragon', 'blueberries']

# %%
nums = [20, 30, 40, 50, 60, 70]
nums.pop()
# Out:
# 70

# %%
nums
# Out:
# [20, 30, 40, 50, 60]

# %%
temp = [2,3,4,5,6,7]
temp.clear()

# %%
temp
# Out:
# []

# %%
temp = [2,3,4,5,6,7]

del temp[4]

# %%
temp
# Out:
# [2, 3, 4, 5, 7]

# %%
mixed_list = ['shashi',True,['Hey',"shashi"],3.8,90,(45,89),{'shashi':'DS'}]

# %%
mixed_list
# Out:
# ['shashi', True, ['Hey', 'shashi'], 3.8, 90, (45, 89), {'shashi': 'DS'}]

# %%
mixed_list[-1]
# Out:
# {'shashi': 'DS'}

# %%
mixed_list[0]
# Out:
# 'shashi'

# %%
mixed_list[0:2]
# Out:
# ['shashi', True]
